# %% [markdown]
# Day 1: Python Basics 🐍
#
# 📚 Topics Covered
#
# What is Python?
#
# Installing Python
#
# Variables
#
# Data Types
#
# User Input
#
# Comments
#
# Basic Output

# %% [markdown]
# 1️⃣ What is Python?
#
# Python is a high-level, easy-to-learn programming language used for:
#
# Data Analysis
#
# Machine Learning
#
# Artificial Intelligence
#
# Web Development
#
# Automation
#
# Cloud Computing

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# 2️⃣ Variables
#
# Variables store data.

# %%
name = "Kirubashini"
age = 22
cgpa = 8.5

print(name)
print(age)
print(cgpa)
# Out:
# Kirubashini
# 22
# 8.5

# %%
#3️⃣ Data Types
name = "Python"      # String
age = 22             # Integer
salary = 50000.50    # Float
is_student = True    # Boolean

print(type(name))
print(type(age))
print(type(salary))
print(type(is_student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
#4️⃣ Taking User Input
name = input("Enter your name: ")
print("Welcome", name)
# Out:
# Enter your name: Kirubashini
# Welcome Kirubashini

# %% [markdown]
# 5️⃣ Comments
#
# Single-line comment
# # This is a comment
# print("Python")
#
# Multi-line comment
#
# """
# This is
# a multi-line
# comment
# """

# %%
#6️⃣ String Formatting
name = "Kirubashini"
role = "AI Engineer"

print(f"My name is {name} and I want to become an {role}")
# Out:
# My name is Kirubashini and I want to become an AI Engineer

# %% [markdown]
# 7️⃣ Mini Practice Programs

# %%
#Program 1: Personal Introduction
name = input("Enter your name: ")
college = input("Enter your college: ")

print(f"Hi, I am {name} from {college}")
# Out:
# Enter your name: Kirubashini
# Enter your college: KRCT
# Hi, I am Kirubashini from KRCT

# %%
#Program 2: Add Two Numbers
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Sum =", a + b)
# Out:
# Enter first number: 586
# Enter second number: 470
# Sum = 1056

# %%
#Program 3: Simple Interest
p = float(input("Principal: "))
r = float(input("Rate: "))
t = float(input("Time: "))

si = (p * r * t) / 100

print("Simple Interest =", si)
# Out:
# Principal: 3000
# Rate: 3
# Time: 1
# Simple Interest = 90.0

# %% [markdown]
# 🎯 Day 1 Challenge
#
# Create a Python program that asks for:
#
# Name
#
# Age
#
# Dream Job
#
# and prints:
#
# ----- Profile-----
#
# Name      : Kirubashini
#
# Age       : 22
#
# Dream Job : AI Engineer
